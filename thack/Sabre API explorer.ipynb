# %%
import time
import requests
import base64
import types
import re
import warnings

class Sabre(object):
    token = None
    APIS = {
        'v1.shop.flights.fares' : ('GET', '/v1/shop/flights/fares', 'Lead Price Calendar API'),
        'v1.historical.shop.flights.fares' : ('GET', '/v1/historical/shop/flights/fares', 'Low Fare History API'),
        'v1.lists.supported.shop.flights.origins.destinations' : ('GET', '/v1/lists/supported/shop/flights/origins-destinations', 'City Pairs Lookup API'),
        'v1.shop.calendar.flights' : ('POST', '/v1.8.1/shop/calendar/flights', 'Advanced Calendar Search API'),
        'v1.lists.supported.pointofsalecountries' : ('GET', '/v1/lists/supported/pointofsalecountries', 'Point of Sale Country Code Lookup API'),
        'v1.lists.supported.shop.themes.theme' : ('GET', '/v1/lists/supported/shop/themes/{theme}', 'Theme Airport Lookup API'),
        'v1.auth.token' : ('POST', '/v1/auth/token', 'Authentication Request'),
        'v1.lists.utilities.airlines.alliances' : ('GET', '/v1/lists/utilities/airlines/alliances/', 'Airline Alliance Lookup API'),
        'v1.historical.flights.fares' : ('GET', '/v1/historical/flights/fares', 'Fare Range API'),
        'v1.forecast.flights.fares' : ('GET', '/v1/forecast/flights/fares', 'Low Fare Forecast API'),
        'v1.lists.supported.cities' : ('GET', '/v1/lists/supported/cities', 'Multi-Airport City Lookup API'),
        'v1.lists.top.destinations' : ('GET', '/v1/lists/top/destinations', 'Top Destinations API'),
        'v1.lists.supported.countries' : ('GET', '/v1/lists/supported/countries', 'Countries Lookup API'),
        'v1.lists.supported.cities.airports' : ('GET', '/v1/lists/supported/cities/{city}/airports/', 'Airports at Cities Lookup API'),
        'v1.shop.altdates.flights' : ('POST', '/v1.8.6/shop/altdates/flights', 'Alternate Date API'),
        'v1.lists.supported.shop.themes' : ('GET', '/v1/lists/supported/shop/themes/', 'Travel Theme Lookup API'),
        'v1.lists.supported.historical.seasonality.airports' : ('GET', '/v1/lists/supported/historical/seasonality/airports', 'Travel Seasonality Airports Lookup API'),
        'v2.shop.cars' : ('POST', '/v2.4.0/shop/cars', 'Car Availability (beta) API'),
        'v3.book.flights.seatmaps' : ('POST', '/v3.0.0/book/flights/seatmaps?mode=seatmaps', 'Seat Map (beta) API'),
        'v1.historical.flights.destination.seasonality' : ('GET', '/v1/historical/flights/{destination}/seasonality', 'Travel Seasonality API'),
        'v1.lists.utilities.airlines.' : ('GET', '/v1/lists/utilities/airlines/', 'Airline Lookup API'),
        'v1.lists.utilities.aircraft.equipment' : ('GET', '/v1/lists/utilities/aircraft/equipment/', 'Aircraft Equipment Lookup API'),
        'v1.shop.flights' : ('GET', '/v1/shop/flights', 'InstaFlights Search API'),
    }
    
    def __init__(self, client_id, client_secret, server='https://api.test.sabre.com'):
        self.client_id = client_id
        self.client_secret = client_secret
        self.server = server
        self.credentials = self.encode_credentials()  
        
        class Container(object):
            def __call__(self, *args, **kwargs):
                return self._call(self.endpoint, *args, **kwargs)
            
        self.api = Container()
        
        for api_name, (method, endpoint, description) in self.APIS.items():
            parts = api_name.split('.')
            obj = self.api
            for part in parts:
                if getattr(obj, part, None) is None:
                    setattr(obj, part, Container())
                obj = getattr(obj, part)
                    
            def fn(s, endpoint, *args, **kwargs):
                e = endpoint
                if '{' in endpoint:
                    e = endpoint.format(**kwargs)
                    for arg in re.findall(r'{(\w+)}', endpoint):
                        del kwargs[arg]
                
                if method == 'GET':
                    kwargs = {"params": kwargs}
                else:
                    kwargs = {"data": kwargs}
                    
                result = self.call_method(method.lower(), self.server + e, *args, **kwargs)
                assert result.status_code is 200, u"Got a {} (expecting 200): {}".format(result.status_code, result.json())
                return result.json()
            
            obj.endpoint = endpoint
            obj._call = types.MethodType(fn, obj, Container)
        
    def is_valid(self):
        self.last_check = time.time()
        if self.token and self.token['expires'] < self.last_check:
            return True
        return False
        
    def get_token(self):
        if self.is_valid():
            return self.token
        headers = {'Authorization': 'Basic ' + self.credentials}
        params = {'grant_type': 'client_credentials'}
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            r = requests.post(self.server + '/v1/auth/token', headers=headers, data=params)
        assert r.status_code is 200, 'Expecting 200 answer, got {} instead'.format(r.status_code)
        self.token = r.json()
        self.token['expires'] = self.last_check + self.token['expires_in']
        return self.token
        
    def encode_credentials(self):
        return base64.b64encode("{client_id}:{client_secret}".format(
                   client_id=base64.b64encode(self.client_id),
                   client_secret=base64.b64encode(self.client_secret)))
    
    def call_method(self, method, *args, **kwargs):
        if kwargs is None:
            kwargs = {}
        kwargs['headers'] = kwargs.get('headers', {})
        kwargs['headers'].update(Authorization='Bearer ' + self.get_token()[u'access_token'])
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            return getattr(requests, method)(*args, **kwargs)
    
    def get(self, *args, **kwargs):
        return self.call_method('get', *args, **kwargs)
    
    def post(self, *args, **kwargs):
        return self.call_method('post', *args, **kwargs)
    
    def api_list(self):
        for api_name, (method, endpoint, description) in self.APIS.items():
            print(u"{}: {} (endpoint: {} {})".format(api_name, description, method, endpoint))

# %%
client_id = 'V1:8y1tk3qc9kb9s0ta:DEVCENTER:EXT'
client_secret = 'hCfAs6B6'

# %%
sabre = Sabre(client_id, client_secret)

# %%
sabre.api_list()
# Out:
# v1.shop.flights.fares: Lead Price Calendar API (endpoint: GET /v1/shop/flights/fares)
# v1.historical.shop.flights.fares: Low Fare History API (endpoint: GET /v1/historical/shop/flights/fares)
# v1.lists.supported.shop.flights.origins.destinations: City Pairs Lookup API (endpoint: GET /v1/lists/supported/shop/flights/origins-destinations)
# v1.lists.supported.countries: Countries Lookup API (endpoint: GET /v1/lists/supported/countries)
# v1.lists.supported.pointofsalecountries: Point of Sale Country Code Lookup API (endpoint: GET /v1/lists/supported/pointofsalecountries)
# v1.lists.supported.shop.themes.theme: Theme Airport Lookup API (endpoint: GET /v1/lists/supported/shop/themes/{theme})
# v1.auth.token: Authentication Request (endpoint: POST /v1/auth/token)
# v1.lists.utilities.airlines.alliances: Airline Alliance Lookup API (endpoint: GET /v1/lists/utilities/airlines/alliances/)
# v1.historical.flights.fares: Fare Range API (endpoint: GET /v1/historical/flights/fares)
# v1.forecast.flights.fares: Low Fare Forecast API (endpoint: GET /v1/forecast/flights/fares)
# v1.lists.supported.cities: Multi-Airport City Lookup API (endpoint: GET /v1/lists/supported/cities)
# v1.lists.supported.cities.airports: Airports at Cities Lookup API (endpoint: GET /v1/lists/supported/cities/{city}/airports/)
# v1.shop.calendar.flights: Advanced Calendar Search API (endpoint: POST /v1.8.1/shop/calendar/flights)
# v1.lists.top.destinations: Top Destinations API (endpoint: GET /v1/lists/top/destinations)
# v1.shop.altdates.flights: Alternate Date API (endpoint: POST /v1.8.6/shop/altdates/flights)
# v1.lists.supported.shop.themes: Travel Theme Lookup API (endpoint: GET /v1/lists/supported/shop/themes/)
# v1.lists.supported.historical.seasonality.airports: Travel Seasonality Airports Lookup API (endpoint: GET /v1/lists/supported/historical/seasonality/airports)
# v2.shop.cars: Car Availability (beta) API (endpoint: POST /v2.4.0/shop/cars)
# v3.book.flights.seatmaps: Seat Map (beta) API (endpoint: POST /v3.0.0/book/flights/seatmaps?mode=seatmaps)
# v1.historical.flights.destination.seasonality: Travel Seasonality API (endpoint: GET /v1/historical/flights/{destination}/seasonality)
# v1.lists.utilities.airlines.: Airline Lookup API (endpoint: GET /v1/lists/utilities/airlines/)
# v1.lists.utilities.aircraft.equipment: Aircraft Equipment Lookup API (endpoint: GET /v1/lists/utilities/aircraft/equipment/)
# v1.shop.flights: InstaFlights Search API (endpoint: GET /v1/shop/flights)

# %%
sabre.api.v1.lists.supported.countries()
# Out:
# {u'DestinationCountries': [{u'CountryCode': u'AG',
#    u'CountryName': u'Antigua And Barbuda'},
#   {u'CountryCode': u'AR', u'CountryName': u'Argentina'},
#   {u'CountryCode': u'AM', u'CountryName': u'Armenia'},
#   {u'CountryCode': u'AW', u'CountryName': u'Aruba'},
#   {u'CountryCode': u'AU', u'CountryName': u'Australia'},
#   {u'CountryCode': u'AT', u'CountryName': u'Austria'},
#   {u'CountryCode': u'BS', u'CountryName': u'Bahamas'},
#   {u'CountryCode': u'BB', u'CountryName': u'Barbados'},
#   {u'CountryCode': u'BE', u'CountryName': u'Belgium'},
#   {u'CountryCode': u'BM', u'CountryName': u'Bermuda'},
#   {u'CountryCode': u'BR', u'CountryName': u'Brazil'},
#   {u'CountryCode': u'BG', u'CountryName': u'Bulgaria'},
#   {u'CountryCode': u'CA', u'CountryName': u'Canada'},
#   {u'CountryCode': u'KY', u'CountryName': u'Cayman Islands'},
#   {u'CountryCode': u'CL', u'CountryName': u'Chile'},
#   {u'CountryCode': u'CN', u'CountryName': u'China'},
#   {u'CountryCode': u'CO', u'CountryName': u'Colombia'},
#   {u'CountryCode': u'CR', u'CountryName': u'Costa Rica'},
#   {u'CountryCode': u'HR', u'CountryName': u'Croatia'},
#   {u'CountryCode': u'CY', u'CountryName': u'Cyprus'},
#   {u'CountryCode': u'CZ', u'CountryName': u'Czech Republic'},
#   {u'CountryCode': u'DK', u'CountryName': u'Denmark'},
#   {u'CountryCode': u'DO', u'CountryName': u'Dominican Republic'},
#   {u'CountryCode': u'EC', u'CountryName': u'Ecuador'},
#   {u'CountryCode': u'EG', u'CountryName': u'Egypt'},
#   {u'CountryCode': u'SV', u'CountryName': u'El Salvador'},
#   {u'CountryCode': u'FR', u'CountryName': u'France'},
#   {u'CountryCode': u'PF', u'CountryName': u'French Polynesia'},
#   {u'CountryCode': u'GE', u'CountryName': u'Georgia'},
#   {u'CountryCode': u'DE', u'CountryName': u'Germany'},
#   {u'CountryCode': u'GR', u'CountryName': u'Greece'},
#   {u'CountryCode': u'GT', u'CountryName': u'Guatemala'},
#   {u'CountryCode': u'GY', u'CountryName': u'Guyana'},
#   {u'CountryCode': u'HT', u'CountryName': u'Haiti'},
#   {u'CountryCode': u'HK', u'CountryName': u'Hong Kong'},
#   {u'CountryCode': u'HU', u'CountryName': u'Hungary'},
#   {u'CountryCode': u'IN', u'CountryName': u'India'},
#   {u'CountryCode': u'ID', u'CountryName': u'Indonesia'},
#   {u'CountryCode': u'IE', u'CountryName': u'Ireland'},
#   {u'CountryCode': u'IL', u'CountryName': u'Israel'},
#   {u'CountryCode': u'IT', u'CountryName': u'Italy'},
#   {u'CountryCode': u'JM', u'CountryName': u'Jamaica'},
#   {u'CountryCode': u'JP', u'CountryName': u'Japan'},
#   {u'CountryCode': u'KR', u'CountryName': u'Korea - Republic Of'},
#   {u'CountryCode': u'KG', u'CountryName': u'Kyrgyzstan'},
#   {u'CountryCode': u'LB', u'CountryName': u'Lebanon'},
#   {u'CountryCode': u'MY', u'CountryName': u'Malaysia'},
#   {u'CountryCode': u'MV', u'CountryName': u'Maldives'},
#   {u'CountryCode': u'MX', u'CountryName': u'Mexico'},
#   {u'CountryCode': u'MA', u'CountryName': u'Morocco'},
#   {u'CountryCode': u'NL', u'CountryName': u'Netherlands'},
#   {u'CountryCode': u'AN', u'CountryName': u'Netherlands Antilles'},
#   {u'CountryCode': u'NI', u'CountryName': u'Nicaragua'},
#   {u'CountryCode': u'NO', u'CountryName': u'Norway'},
#   {u'CountryCode': u'PK', u'CountryName': u'Pakistan'},
#   {u'CountryCode': u'PA', u'CountryName': u'Panama'},
#   {u'CountryCode': u'PE', u'CountryName': u'Peru'},
#   {u'CountryCode': u'PH', u'CountryName': u'Philippines'},
#   {u'CountryCode': u'PT', u'CountryName': u'Portugal'},
#   {u'CountryCode': u'PR', u'CountryName': u'Puerto Rico'},
#   {u'CountryCode': u'RU', u'CountryName': u'Russian Federation'},
#   {u'CountryCode': u'LC', u'CountryName': u'Saint Lucia'},
#   {u'CountryCode': u'RS', u'CountryName': u'Serbia'},
#   {u'CountryCode': u'SG', u'CountryName': u'Singapore'},
#   {u'CountryCode': u'ES', u'CountryName': u'Spain'},
#   {u'CountryCode': u'LK', u'CountryName': u'Sri Lanka'},
#   {u'CountryCode': u'SR', u'CountryName': u'Suriname'},
#   {u'CountryCode': u'SE', u'CountryName': u'Sweden'},
#   {u'CountryCode': u'CH', u'CountryName': u'Switzerland'},
#   {u'CountryCode': u'TW', u'CountryName': u'Taiwan'},
#   {u'CountryCode': u'TJ', u'CountryName': u'Tajikistan'},
#   {u'CountryCode': u'TH', u'CountryName': u'Thailand'},
#   {u'CountryCode': u'TT', u'CountryName': u'Trinidad And Tobago'},
#   {u'CountryCode': u'TR', u'CountryName': u'Turkey'},
#   {u'CountryCode': u'TC', u'CountryName': u'Turks And Caicos Islands'},
#   {u'CountryCode': u'UA', u'CountryName': u'Ukraine'},
#   {u'CountryCode': u'AE', u'CountryName': u'United Arab Emirates'},
#   {u'CountryCode': u'GB', u'CountryName': u'United Kingdom'},
#   {u'CountryCode': u'US', u'CountryName': u'United States'},
#   {u'CountryCode': u'UY', u'CountryName': u'Uruguay'},
#   {u'CountryCode': u'UZ', u'CountryName': u'Uzbekistan'},
#   {u'CountryCode': u'VE', u'CountryName': u'Venezuela'},
#   {u'CountryCode': u'VN', u'CountryName': u'Viet Nam'},
#   {u'CountryCode': u'VI', u'CountryName': u'Virgin Islands (U.S.)'}],
#  u'Links': [{u'href': u'https://api.test.sabre.com/v1/lists/supported/countries',
#    u'rel': u'self'},
#   {u'href': u'https://api.test.sabre.com/v1/lists/supported/countries?pointofsalecountry=<pointofsalecountry>',
#    u'rel': u'linkTemplate'}],
#  u'OriginCountries': [{u'CountryCode': u'AR', u'CountryName': u'Argentina'},
#   {u'CountryCode': u'BE', u'CountryName': u'Belgium'},
#   {u'CountryCode': u'CL', u'CountryName': u'Chile'},
#   {u'CountryCode': u'CY', u'CountryName': u'Cyprus'},
#   {u'CountryCode': u'DK', u'CountryName': u'Denmark'},
#   {u'CountryCode': u'FR', u'CountryName': u'France'},
#   {u'CountryCode': u'GR', u'CountryName': u'Greece'},
#   {u'CountryCode': u'IT', u'CountryName': u'Italy'},
#   {u'CountryCode': u'NL', u'CountryName': u'Netherlands'},
#   {u'CountryCode': u'NO', u'CountryName': u'Norway'},
#   {u'CountryCode': u'PT', u'CountryName': u'Portugal'},
#   {u'CountryCode': u'PR', u'CountryName': u'Puerto Rico'},
#   {u'CountryCode': u'RU', u'CountryName': u'Russian Federation'},
#   {u'CountryCode': u'ES', u'CountryName': u'Spain'},
#   {u'CountryCode': u'SE', u'CountryName': u'Sweden'},
#   {u'CountryCode': u'TR', u'CountryName': u'Turkey'},
#   {u'CountryCode': u'GB', u'CountryName': u'United Kingdom'},
#   {u'CountryCode': u'US', u'CountryName': u'United States'}],
#  u'PointOfSale': u'US'}

# %%
sabre.api.v1.lists.supported.shop.flights.origins.destinations()
# Out:
# {u'Links': [{u'href': u'https://api.test.sabre.com/v1/lists/supported/shop/flights/origins-destinations',
#    u'rel': u'self'},
#   {u'href': u'https://api.test.sabre.com/v1/lists/supported/shop/flights/origins-destinations?destinationregion=<destinationregion>&originregion=<originregion>&destinationcountry=<destinationcountry>&origincountry=<origincountry>&pointofsalecountry=<pointofsalecountry>',
#    u'rel': u'linkTemplate'}],
#  u'OriginDestinationLocations': [{u'DestinationLocation': {u'AirportCode': u'MCO',
#     u'AirportName': u'Orlando International Airport',
#     u'CityName': u'Orlando',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ABE-MCO',
#    u'OriginLocation': {u'AirportCode': u'ABE',
#     u'AirportName': u'Lehigh Valley International Airport',
#     u'CityName': u'Allentown',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AER-MOW',
#    u'OriginLocation': {u'AirportCode': u'AER',
#     u'AirportName': u'Adler/Sochi',
#     u'CityName': u'Adler/Sochi',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BCN',
#     u'AirportName': u'Barcelona',
#     u'CityName': u'Barcelona',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AGP-BCN',
#    u'OriginLocation': {u'AirportCode': u'AGP',
#     u'AirportName': u'Malaga',
#     u'CityName': u'Malaga',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LON',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'London',
#     u'CountryCode': u'GB',
#     u'CountryName': u'United Kingdom',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AGP-LON',
#    u'OriginLocation': {u'AirportCode': u'AGP',
#     u'AirportName': u'Malaga',
#     u'CityName': u'Malaga',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BCN',
#     u'AirportName': u'Barcelona',
#     u'CityName': u'Barcelona',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AMS-BCN',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BKK',
#     u'AirportName': u'International',
#     u'CityName': u'Bangkok',
#     u'CountryCode': u'TH',
#     u'CountryName': u'Thailand',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'AMS-BKK',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'CUR',
#     u'AirportName': u'Aeropuerto Hato',
#     u'CityName': u'Curacao',
#     u'CountryCode': u'AN',
#     u'CountryName': u'Netherlands Antilles',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AMS-CUR',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'DPS',
#     u'AirportName': u'Ngurah Rai',
#     u'CityName': u'Denpasar Bali',
#     u'CountryCode': u'ID',
#     u'CountryName': u'Indonesia',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'AMS-DPS',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'DXB',
#     u'AirportName': u'Dubai International Airport',
#     u'CityName': u'Dubai',
#     u'CountryCode': u'AE',
#     u'CountryName': u'United Arab Emirates',
#     u'RegionName': u'Middle East'},
#    u'OriginDestinationLocations': u'AMS-DXB',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'IST',
#     u'AirportName': u'Ataturk',
#     u'CityName': u'Istanbul',
#     u'CountryCode': u'TR',
#     u'CountryName': u'Turkey',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AMS-IST',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'JKT',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Jakarta',
#     u'CountryCode': u'ID',
#     u'CountryName': u'Indonesia',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'AMS-JKT',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'KUL',
#     u'AirportName': u"Kuala Lumpur Int'l",
#     u'CityName': u'Kuala Lumpur',
#     u'CountryCode': u'MY',
#     u'CountryName': u'Malaysia',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'AMS-KUL',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAX',
#     u'AirportName': u'Los Angeles International Airport',
#     u'CityName': u'Los Angeles',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AMS-LAX',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LON',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'London',
#     u'CountryCode': u'GB',
#     u'CountryName': u'United Kingdom',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AMS-LON',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'NYC',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'New York',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AMS-NYC',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PBM',
#     u'AirportName': u'Zanderij Intl',
#     u'CityName': u'Paramaribo',
#     u'CountryCode': u'SR',
#     u'CountryName': u'Suriname',
#     u'RegionName': u'Latin America'},
#    u'OriginDestinationLocations': u'AMS-PBM',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'SIN',
#     u'AirportName': u'Changi',
#     u'CityName': u'Singapore',
#     u'CountryCode': u'SG',
#     u'CountryName': u'Singapore',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'AMS-SIN',
#    u'OriginLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'AGP',
#     u'AirportName': u'Malaga',
#     u'CityName': u'Malaga',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ARN-AGP',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BCN',
#     u'AirportName': u'Barcelona',
#     u'CityName': u'Barcelona',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ARN-BCN',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BEY',
#     u'AirportName': u'International',
#     u'CityName': u'Beirut',
#     u'CountryCode': u'LB',
#     u'CountryName': u'Lebanon',
#     u'RegionName': u'Middle East'},
#    u'OriginDestinationLocations': u'ARN-BEY',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BKK',
#     u'AirportName': u'International',
#     u'CityName': u'Bangkok',
#     u'CountryCode': u'TH',
#     u'CountryName': u'Thailand',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'ARN-BKK',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'DXB',
#     u'AirportName': u'Dubai International Airport',
#     u'CityName': u'Dubai',
#     u'CountryCode': u'AE',
#     u'CountryName': u'United Arab Emirates',
#     u'RegionName': u'Middle East'},
#    u'OriginDestinationLocations': u'ARN-DXB',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'HKT',
#     u'AirportName': u'International',
#     u'CityName': u'Phuket',
#     u'CountryCode': u'TH',
#     u'CountryName': u'Thailand',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'ARN-HKT',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'IST',
#     u'AirportName': u'Ataturk',
#     u'CityName': u'Istanbul',
#     u'CountryCode': u'TR',
#     u'CountryName': u'Turkey',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ARN-IST',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAX',
#     u'AirportName': u'Los Angeles International Airport',
#     u'CityName': u'Los Angeles',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ARN-LAX',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LON',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'London',
#     u'CountryCode': u'GB',
#     u'CountryName': u'United Kingdom',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ARN-LON',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'MIA',
#     u'AirportName': u'Miami International Airport',
#     u'CityName': u'Miami',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ARN-MIA',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'NYC',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'New York',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ARN-NYC',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PAR',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Paris',
#     u'CountryCode': u'FR',
#     u'CountryName': u'France',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ARN-PAR',
#    u'OriginLocation': {u'AirportCode': u'ARN',
#     u'AirportName': u'Arlanda',
#     u'CityName': u'Stockholm',
#     u'CountryCode': u'SE',
#     u'CountryName': u'Sweden',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
#     u'CountryCode': u'NL',
#     u'CountryName': u'Netherlands',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-AMS',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'AXD',
#     u'AirportName': u'Demokritos Airport',
#     u'CityName': u'Alexandroupolis',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-AXD',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BCN',
#     u'AirportName': u'Barcelona',
#     u'CityName': u'Barcelona',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-BCN',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BRU',
#     u'AirportName': u'National',
#     u'CityName': u'Brussels',
#     u'CountryCode': u'BE',
#     u'CountryName': u'Belgium',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-BRU',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'CHQ',
#     u'AirportName': u'Souda',
#     u'CityName': u'Chania',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-CHQ',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'FRA',
#     u'AirportName': u'International',
#     u'CityName': u'Frankfurt',
#     u'CountryCode': u'DE',
#     u'CountryName': u'Germany',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-FRA',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'HER',
#     u'AirportName': u'N. Kazantzakis Apt.',
#     u'CityName': u'Heraklion',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-HER',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'IST',
#     u'AirportName': u'Ataturk',
#     u'CityName': u'Istanbul',
#     u'CountryCode': u'TR',
#     u'CountryName': u'Turkey',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-IST',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'JFK',
#     u'AirportName': u'John F. Kennedy International Airport',
#     u'CityName': u'New York',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATH-JFK',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LCA',
#     u'AirportName': u'Larnaca',
#     u'CityName': u'Larnaca',
#     u'CountryCode': u'CY',
#     u'CountryName': u'Cyprus',
#     u'RegionName': u'Middle East'},
#    u'OriginDestinationLocations': u'ATH-LCA',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'LON',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'London',
#     u'CountryCode': u'GB',
#     u'CountryName': u'United Kingdom',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-LON',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'MIL',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Milan',
#     u'CountryCode': u'IT',
#     u'CountryName': u'Italy',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-MIL',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'MJT',
#     u'AirportName': u'Mytilene',
#     u'CityName': u'Mytilene',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-MJT',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'MUC',
#     u'AirportName': u'Franz Josef Strauss',
#     u'CityName': u'Munich',
#     u'CountryCode': u'DE',
#     u'CountryName': u'Germany',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-MUC',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'NYC',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'New York',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATH-NYC',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PAR',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Paris',
#     u'CountryCode': u'FR',
#     u'CountryName': u'France',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-PAR',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PRG',
#     u'AirportName': u'Ruzyne',
#     u'CityName': u'Prague',
#     u'CountryCode': u'CZ',
#     u'CountryName': u'Czech Republic',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-PRG',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'RHO',
#     u'AirportName': u'Diagoras Airport',
#     u'CityName': u'Rhodes',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-RHO',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'ROM',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Rome',
#     u'CountryCode': u'IT',
#     u'CountryName': u'Italy',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-ROM',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'SKG',
#     u'AirportName': u'Makedonia Apt.',
#     u'CityName': u'Thessaloniki',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-SKG',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'VIE',
#     u'AirportName': u'Vienna International',
#     u'CityName': u'Vienna',
#     u'CountryCode': u'AT',
#     u'CountryName': u'Austria',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATH-VIE',
#    u'OriginLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'BOS',
#     u'AirportName': u'General Edward Lawrence Logan Internatio',
#     u'CityName': u'Boston',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-BOS',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'BWI',
#     u'AirportName': u'Baltimore/Washington International Thurg',
#     u'CityName': u'Baltimore',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-BWI',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'CUN',
#     u'AirportName': u'Cancun',
#     u'CityName': u'Cancun',
#     u'CountryCode': u'MX',
#     u'CountryName': u'Mexico',
#     u'RegionName': u'Latin America'},
#    u'OriginDestinationLocations': u'ATL-CUN',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DCA',
#     u'AirportName': u'Ronald Reagan Washington National Airpor',
#     u'CityName': u'Washington',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-DCA',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DEN',
#     u'AirportName': u'Denver International Airport',
#     u'CityName': u'Denver',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-DEN',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DFW',
#     u'AirportName': u'Dallas/Fort Worth International Airport',
#     u'CityName': u'Dallas',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-DFW',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DTW',
#     u'AirportName': u'Detroit Metropolitan Wayne County Airpor',
#     u'CityName': u'Detroit',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-DTW',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'EWR',
#     u'AirportName': u'Newark Liberty International Airport',
#     u'CityName': u'Newark',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-EWR',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'FLL',
#     u'AirportName': u'Fort Lauderdale - Hollywood Internationa',
#     u'CityName': u'Fort Lauderdale',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-FLL',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'HOU',
#     u'AirportName': u'William P Hobby Airport',
#     u'CityName': u'Houston',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-HOU',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'IAH',
#     u'AirportName': u'Houston George Bush Intercontinental Air',
#     u'CityName': u'Houston',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-IAH',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'IND',
#     u'AirportName': u'Indianapolis International Airport',
#     u'CityName': u'Indianapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-IND',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'JAX',
#     u'AirportName': u'Jacksonville International Airport',
#     u'CityName': u'Jacksonville',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-JAX',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAS',
#     u'AirportName': u'McCarran International Airport',
#     u'CityName': u'Las Vegas',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-LAS',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAX',
#     u'AirportName': u'Los Angeles International Airport',
#     u'CityName': u'Los Angeles',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-LAX',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LGA',
#     u'AirportName': u'LaGuardia Airport',
#     u'CityName': u'New York',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-LGA',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LHR',
#     u'AirportName': u'Heathrow',
#     u'CityName': u'London',
#     u'CountryCode': u'GB',
#     u'CountryName': u'United Kingdom',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'ATL-LHR',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MBJ',
#     u'AirportName': u'Sangster Intl',
#     u'CityName': u'Montego Bay',
#     u'CountryCode': u'JM',
#     u'CountryName': u'Jamaica',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-MBJ',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MCO',
#     u'AirportName': u'Orlando International Airport',
#     u'CityName': u'Orlando',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-MCO',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MDW',
#     u'AirportName': u'Chicago Midway International Airport',
#     u'CityName': u'Chicago',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-MDW',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MEX',
#     u'AirportName': u'Juarez International',
#     u'CityName': u'Mexico City',
#     u'CountryCode': u'MX',
#     u'CountryName': u'Mexico',
#     u'RegionName': u'Latin America'},
#    u'OriginDestinationLocations': u'ATL-MEX',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MIA',
#     u'AirportName': u'Miami International Airport',
#     u'CityName': u'Miami',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-MIA',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-MSP',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MSY',
#     u'AirportName': u'New Orleans Louis Armstrong Airport',
#     u'CityName': u'New Orleans',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-MSY',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'NAS',
#     u'AirportName': u'Intl',
#     u'CityName': u'Nassau',
#     u'CountryCode': u'BS',
#     u'CountryName': u'Bahamas',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-NAS',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'ORD',
#     u'AirportName': u"Chicago O'Hare International Airport",
#     u'CityName': u'Chicago',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-ORD',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'PBI',
#     u'AirportName': u'Palm Beach International Airport',
#     u'CityName': u'West Palm Beach',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-PBI',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'PHL',
#     u'AirportName': u'Philadelphia International Airport',
#     u'CityName': u'Philadelphia',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-PHL',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'PHX',
#     u'AirportName': u'Phoenix Sky Harbor International Airport',
#     u'CityName': u'Phoenix',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-PHX',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'PUJ',
#     u'AirportName': u'Punta Cana',
#     u'CityName': u'Punta Cana',
#     u'CountryCode': u'DO',
#     u'CountryName': u'Dominican Republic',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-PUJ',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'RDU',
#     u'AirportName': u'Raleigh-Durham International Airport',
#     u'CityName': u'Durham',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-RDU',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'SAN',
#     u'AirportName': u'San Diego International Airport',
#     u'CityName': u'San Diego',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-SAN',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'SAT',
#     u'AirportName': u'San Antonio International Airport',
#     u'CityName': u'San Antonio',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-SAT',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'SEA',
#     u'AirportName': u'Seattle Tacoma International Airport',
#     u'CityName': u'Seattle',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-SEA',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'SFO',
#     u'AirportName': u'San Francisco International Airport',
#     u'CityName': u'San Francisco',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-SFO',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'SJU',
#     u'AirportName': u'Luis Muoz Marn International Airport',
#     u'CityName': u'San Juan',
#     u'CountryCode': u'PR',
#     u'CountryName': u'Puerto Rico',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-SJU',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'TPA',
#     u'AirportName': u'Tampa International Airport',
#     u'CityName': u'Tampa',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-TPA',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'YYZ',
#     u'AirportName': u'Pearson International',
#     u'CityName': u'Toronto',
#     u'CountryCode': u'CA',
#     u'CountryName': u'Canada',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'ATL-YYZ',
#    u'OriginLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DEN',
#     u'AirportName': u'Denver International Airport',
#     u'CityName': u'Denver',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AUS-DEN',
#    u'OriginLocation': {u'AirportCode': u'AUS',
#     u'AirportName': u'AustinBergstrom International Airport',
#     u'CityName': u'Austin',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAS',
#     u'AirportName': u'McCarran International Airport',
#     u'CityName': u'Las Vegas',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AUS-LAS',
#    u'OriginLocation': {u'AirportCode': u'AUS',
#     u'AirportName': u'AustinBergstrom International Airport',
#     u'CityName': u'Austin',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAX',
#     u'AirportName': u'Los Angeles International Airport',
#     u'CityName': u'Los Angeles',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AUS-LAX',
#    u'OriginLocation': {u'AirportCode': u'AUS',
#     u'AirportName': u'AustinBergstrom International Airport',
#     u'CityName': u'Austin',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MCO',
#     u'AirportName': u'Orlando International Airport',
#     u'CityName': u'Orlando',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AUS-MCO',
#    u'OriginLocation': {u'AirportCode': u'AUS',
#     u'AirportName': u'AustinBergstrom International Airport',
#     u'CityName': u'Austin',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'SFO',
#     u'AirportName': u'San Francisco International Airport',
#     u'CityName': u'San Francisco',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'AUS-SFO',
#    u'OriginLocation': {u'AirportCode': u'AUS',
#     u'AirportName': u'AustinBergstrom International Airport',
#     u'CityName': u'Austin',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'ATH',
#     u'AirportName': u'Eleftherios Venizelos',
#     u'CityName': u'Athens',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'AXD-ATH',
#    u'OriginLocation': {u'AirportCode': u'AXD',
#     u'AirportName': u'Demokritos Airport',
#     u'CityName': u'Alexandroupolis',
#     u'CountryCode': u'GR',
#     u'CountryName': u'Greece',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'AGP',
#     u'AirportName': u'Malaga',
#     u'CityName': u'Malaga',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'BCN-AGP',
#    u'OriginLocation': {u'AirportCode': u'BCN',
#     u'AirportName': u'Barcelona',
#     u'CityName': u'Barcelona',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'AMS',
#     u'AirportName': u'Amsterdam-Schiphol',
#     u'CityName': u'Amsterdam',
# ...
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PAR',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Paris',
#     u'CountryCode': u'FR',
#     u'CountryName': u'France',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-PAR',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PRG',
#     u'AirportName': u'Ruzyne',
#     u'CityName': u'Prague',
#     u'CountryCode': u'CZ',
#     u'CountryName': u'Czech Republic',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-PRG',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'PUJ',
#     u'AirportName': u'Punta Cana',
#     u'CityName': u'Punta Cana',
#     u'CountryCode': u'DO',
#     u'CountryName': u'Dominican Republic',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MOW-PUJ',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'ROM',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Rome',
#     u'CountryCode': u'IT',
#     u'CountryName': u'Italy',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-ROM',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'ROV',
#     u'AirportName': u'Rostov',
#     u'CityName': u'Rostov',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-ROV',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'SGN',
#     u'AirportName': u'Ho Chi Minh City',
#     u'CityName': u'Ho Chi Minh City',
#     u'CountryCode': u'VN',
#     u'CountryName': u'Viet Nam',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'MOW-SGN',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'SIP',
#     u'AirportName': u'Simferopol',
#     u'CityName': u'Simferopol',
#     u'CountryCode': u'UA',
#     u'CountryName': u'Ukraine',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-SIP',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'SSH',
#     u'AirportName': u'Ophira',
#     u'CityName': u'Sharm El Sheikh',
#     u'CountryCode': u'EG',
#     u'CountryName': u'Egypt',
#     u'RegionName': u'Middle East'},
#    u'OriginDestinationLocations': u'MOW-SSH',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'SVX',
#     u'AirportName': u'Ekaterinburg',
#     u'CityName': u'Ekaterinburg',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-SVX',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'TAS',
#     u'AirportName': u'Vostochny',
#     u'CityName': u'Tashkent',
#     u'CountryCode': u'UZ',
#     u'CountryName': u'Uzbekistan',
#     u'RegionName': u'Asia Pacific'},
#    u'OriginDestinationLocations': u'MOW-TAS',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'TBS',
#     u'AirportName': u'Novo Alexeyevka',
#     u'CityName': u'Tbilisi',
#     u'CountryCode': u'GE',
#     u'CountryName': u'Georgia',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-TBS',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'TCI',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Tenerife',
#     u'CountryCode': u'ES',
#     u'CountryName': u'Spain',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-TCI',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'TIV',
#     u'AirportName': u'Tivat',
#     u'CityName': u'Tivat',
#     u'CountryCode': u'RS',
#     u'CountryName': u'Serbia',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-TIV',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'TLV',
#     u'AirportName': u'Ben Gurion Intl',
#     u'CityName': u'Tel Aviv Yafo',
#     u'CountryCode': u'IL',
#     u'CountryName': u'Israel',
#     u'RegionName': u'Middle East'},
#    u'OriginDestinationLocations': u'MOW-TLV',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'VIE',
#     u'AirportName': u'Vienna International',
#     u'CityName': u'Vienna',
#     u'CountryCode': u'AT',
#     u'CountryName': u'Austria',
#     u'RegionName': u'Europe'},
#    u'OriginDestinationLocations': u'MOW-VIE',
#    u'OriginLocation': {u'AirportCode': u'MOW',
#     u'AirportName': u'Metropolitan Area',
#     u'CityName': u'Moscow',
#     u'CountryCode': u'RU',
#     u'CountryName': u'Russian Federation',
#     u'RegionName': u'Europe'}},
#   {u'DestinationLocation': {u'AirportCode': u'ATL',
#     u'AirportName': u'Hartsfield-Jackson Atlanta International',
#     u'CityName': u'Atlanta',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-ATL',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'BOS',
#     u'AirportName': u'General Edward Lawrence Logan Internatio',
#     u'CityName': u'Boston',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-BOS',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'CUN',
#     u'AirportName': u'Cancun',
#     u'CityName': u'Cancun',
#     u'CountryCode': u'MX',
#     u'CountryName': u'Mexico',
#     u'RegionName': u'Latin America'},
#    u'OriginDestinationLocations': u'MSP-CUN',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DCA',
#     u'AirportName': u'Ronald Reagan Washington National Airpor',
#     u'CityName': u'Washington',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-DCA',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DEN',
#     u'AirportName': u'Denver International Airport',
#     u'CityName': u'Denver',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-DEN',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'DFW',
#     u'AirportName': u'Dallas/Fort Worth International Airport',
#     u'CityName': u'Dallas',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-DFW',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'FLL',
#     u'AirportName': u'Fort Lauderdale - Hollywood Internationa',
#     u'CityName': u'Fort Lauderdale',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-FLL',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'IAH',
#     u'AirportName': u'Houston George Bush Intercontinental Air',
#     u'CityName': u'Houston',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-IAH',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAS',
#     u'AirportName': u'McCarran International Airport',
#     u'CityName': u'Las Vegas',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-LAS',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LAX',
#     u'AirportName': u'Los Angeles International Airport',
#     u'CityName': u'Los Angeles',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-LAX',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'LGA',
#     u'AirportName': u'LaGuardia Airport',
#     u'CityName': u'New York',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-LGA',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MBJ',
#     u'AirportName': u'Sangster Intl',
#     u'CityName': u'Montego Bay',
#     u'CountryCode': u'JM',
#     u'CountryName': u'Jamaica',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-MBJ',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MCO',
#     u'AirportName': u'Orlando International Airport',
#     u'CityName': u'Orlando',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-MCO',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MDW',
#     u'AirportName': u'Chicago Midway International Airport',
#     u'CityName': u'Chicago',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-MDW',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'MIA',
#     u'AirportName': u'Miami International Airport',
#     u'CityName': u'Miami',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-MIA',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   {u'DestinationLocation': {u'AirportCode': u'ORD',
#     u'AirportName': u"Chicago O'Hare International Airport",
#     u'CityName': u'Chicago',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'},
#    u'OriginDestinationLocations': u'MSP-ORD',
#    u'OriginLocation': {u'AirportCode': u'MSP',
#     u'AirportName': u'Minneapolis-Saint Paul International Air',
#     u'CityName': u'Minneapolis',
#     u'CountryCode': u'US',
#     u'CountryName': u'United States',
#     u'RegionName': u'North America'}},
#   ...]}

# %%
import spotipy

# %%
spotipy.
